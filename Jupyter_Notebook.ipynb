# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Zeynep Sağlam**

# %% [markdown]
# Data scientist in F1

# %% [markdown]
# *The reason why I'm interested in data science is because I work in the laboratory so I am intertwined with data, and I like coding. I am also intrigued by the fact that data science forms the basis of artificial intelligence. I think and see that it will give me a lot of opportunity in terms of my career to improve myself in this field.*

# %% [markdown]
# ### Takes a number from the user and adds five to that number. Then it says the new number is the lucky number of the user.

# %%
x=int(input("Please enter an integer number ="))
y=x+5
print("This is your lucky number now...",y)

# %% [markdown]
# You can reach the course page from  [this link](https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook).
# ***
# | Day           | Month         | Year  |
# | ------------- |:-------------:| -----:|
# | 12            | May           | 2013  |
# | 24            | November      | 1995  |
# | 7             | January       | 2001  |
